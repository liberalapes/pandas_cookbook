# %% [markdown]
# # Pandas Cookbook

# %% [markdown]
# ## 10장. 시계열 분석

# %% [markdown]
# https://github.com/PacktPublishing/Pandas-Cookbook/tree/master/data

# %% [markdown]
# ### 소개

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 파이썬과 Pandas의 날짜 도구 차이 이해

# %%
import datetime

date = datetime.date(year = 2013, month = 6, day = 7)
time = datetime.time(hour = 12, minute = 30, second = 19, microsecond = 463198)
dt = datetime.datetime(year = 2013,  month = 6, day = 7, hour = 12, minute = 30, second = 19, microsecond = 463198)

print ("date is ", date)
print ("time is ", time)
print ("datetime is ", dt)
# Out:
# date is  2013-06-07
# time is  12:30:19.463198
# datetime is  2013-06-07 12:30:19.463198

# %%
td = datetime.timedelta(weeks = 2, days = 5, hours = 10, minutes = 20, seconds = 6.73, milliseconds = 99, microseconds = 8)
print(td)
# Out:
# 19 days, 10:20:06.829008

# %%
print("new date is", date + td)
print("new datetime is", dt + td)
# Out:
# new date is 2013-06-26
# new datetime is 2013-06-26 22:50:26.292206

# %%
time + td
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1bc8485497ad> in <module>()
# ----> 1 time + td
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'datetime.timedelta'

# %%
pd.Timestamp(year = 2012, month = 12, day = 21, hour = 5, minute =10, second = 8, microsecond =99)
# Out:
# Timestamp('2012-12-21 05:10:08.000099')

# %%
pd.Timestamp('2016/1/10')
# Out:
# Timestamp('2016-01-10 00:00:00')

# %%
pd.Timestamp('2014-5/10')
# Out:
# Timestamp('2014-05-10 00:00:00')

# %%
pd.Timestamp('Jan 3, 2019 20:45.56')
# Out:
# Timestamp('2019-01-03 20:45:33')

# %%
pd.Timestamp('2016-01-05T05:34:43.1234556789')
# Out:
# Timestamp('2016-01-05 05:34:43.123455678')

# %%
pd.Timestamp(500)
# Out:
# Timestamp('1970-01-01 00:00:00.000000500')

# %%
pd.Timestamp(5000, unit = 'D')
# Out:
# Timestamp('1983-09-10 00:00:00')

# %%
pd.to_datetime('2015-5-13')
# Out:
# Timestamp('2015-05-13 00:00:00')

# %%
pd.to_datetime('2015-13-05', dayfirst = True)
# Out:
# Timestamp('2015-05-13 00:00:00')

# %%
pd.to_datetime('Start Date: Sep 30, 2017 Start Time: 1:30 pm', format = 'Start Date: %b %d, %Y Start Time: %I:%M %p')
# Out:
# Timestamp('2017-09-30 13:30:00')

# %%
pd.to_datetime(100, unit ='D', origin = '2013-1-1')
# Out:
# Timestamp('2013-04-11 00:00:00')

# %%
s = pd.Series([10, 100, 1000, 10000])
pd.to_datetime(s, unit = 'D')
# Out:
# 0   1970-01-11
# 1   1970-04-11
# 2   1972-09-27
# 3   1997-05-19
# dtype: datetime64[ns]

# %%
s = pd.Series(['12-5-2015', '14-1-2013', '20/12/2017', '40/23/2017'])
pd.to_datetime(s, dayfirst=True, errors = 'coerce')
# Out:
# 0   2015-05-12
# 1   2013-01-14
# 2   2017-12-20
# 3          NaT
# dtype: datetime64[ns]

# %%
pd.to_datetime(['Aug 2 1999 3:45:56', '10/31/2017'])
# Out:
# DatetimeIndex(['1999-08-02 03:45:56', '2017-10-31 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
pd.Timedelta('12 days 5 hour 3 minutes 123456789 nanoseconds')
# Out:
# Timedelta('12 days 05:03:00.123456')

# %%
pd.Timedelta(days = 5, minutes = 7.34)
# Out:
# Timedelta('5 days 00:07:20.400000')

# %%
pd.Timedelta(100, unit = 'W')
# Out:
# Timedelta('700 days 00:00:00')

# %%
pd.to_timedelta('67:15:45.454')
# Out:
# Timedelta('2 days 19:15:45.454000')

# %%
s = pd.Series([10, 100])
pd.to_timedelta(s, unit = 's')
# Out:
# 0   00:00:10
# 1   00:01:40
# dtype: timedelta64[ns]

# %%
time_strings = ['2 days 24 minutes 89.67 seconds', '00:45:23.6']
pd.to_timedelta(time_strings)
# Out:
# TimedeltaIndex(['2 days 00:25:29.670000', '0 days 00:45:23.600000'], dtype='timedelta64[ns]', freq=None)

# %%
pd.Timedelta('12 days 5 hour 3 minutes') * 2
# Out:
# Timedelta('24 days 10:06:00')

# %%
pd.Timestamp('1/1/2017') + pd.Timedelta('12 days 5 hours 3 minutes') * 2
# Out:
# Timestamp('2017-01-25 10:06:00')

# %%
td1 = pd.to_timedelta([10, 100], unit = 's')
td2 = pd.to_timedelta(['3 hours','4 hours'])
td1 + td2
# Out:
# TimedeltaIndex(['03:00:10', '04:01:40'], dtype='timedelta64[ns]', freq=None)

# %%
pd.Timedelta('12 days') / pd.Timedelta('3 days')
# Out:
# 4.0

# %%
ts = pd.Timestamp('2016-10-1 4:23:23.9')
ts.ceil('h')
# Out:
# Timestamp('2016-10-01 05:00:00')

# %%
ts.year, ts.month, ts.day, ts.hour, ts.minute, ts.second
# Out:
# (2016, 10, 1, 4, 23, 23)

# %%
ts.dayofweek, ts.dayofyear, ts.daysinmonth
# Out:
# (5, 275, 31)

# %%
ts.to_pydatetime()
# Out:
# datetime.datetime(2016, 10, 1, 4, 23, 23, 900000)

# %%
td = pd.Timedelta(123.8723, unit = 'h')
td
# Out:
# Timedelta('5 days 03:52:20.280000')

# %%
td.round('min')
# Out:
# Timedelta('5 days 03:52:00')

# %%
td.components
# Out:
# Components(days=5, hours=3, minutes=52, seconds=20, milliseconds=280, microseconds=0, nanoseconds=0)

# %%
td.total_seconds()
# Out:
# 445940.28

# %%
date_string_list = ['Sep 30 1984'] * 10000

# %timeit pd.to_datetime(date_string_list, format='%b %d %Y')

# %timeit pd.to_datetime(date_string_list)
# Out:
# 30.7 ms ± 1.07 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.12 s ± 85.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# - datetime 모듈에 대한 Python 공식문서 : https://docs.python.org/3/library/datetime.html
# - Time series 에 대한 Python 공식문서 : http://pandas.pydata.org/pandas-docs/stable/timeseries.html
# - Time Deltas 에 대한 Python 공식문서 : http://pandas.pydata.org/pandas-docs/stable/timedeltas.html

# %% [markdown]
# ### 시계열을 현명하게 분할하기

# %%
# %pwd
# Out:
# '/Users/chosikc/Sites/PandasCookbook'

# %%
pwd = %pwd
crime = pd.read_hdf(pwd + '/crime.h5', 'crime')
crime.dtypes
# Out:
# OFFENSE_TYPE_ID              category
# OFFENSE_CATEGORY_ID          category
# REPORTED_DATE          datetime64[ns]
# GEO_LON                       float64
# GEO_LAT                       float64
# NEIGHBORHOOD_ID              category
# IS_CRIME                        int64
# IS_TRAFFIC                      int64
# dtype: object

# %%
crime = crime.set_index('REPORTED_DATE')
crime.head()
# Out:
#                                 OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00   traffic-accident-dui-duid    traffic-accident
# 2014-06-29 01:54:00  vehicular-eluding-no-chase    all-other-crimes
# 2014-06-29 02:00:00        disturbing-the-peace     public-disorder
# 2014-06-29 02:18:00                      curfew     public-disorder
# 2014-06-29 04:17:00          aggravated-assault  aggravated-assault
#
#                         GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00 -105.000149  39.745753                        cbd
# 2014-06-29 01:54:00 -104.884660  39.738702                east-colfax
# 2014-06-29 02:00:00 -105.020719  39.706674                athmar-park
# 2014-06-29 02:18:00 -105.001552  39.769505                  sunnyside
# 2014-06-29 04:17:00 -105.018557  39.679229  college-view-south-platte
#
#                      IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2014-06-29 02:01:00         0           1
# ...

# %%
crime.loc['2016-05-12 16:45:00']
# Out:
#                           OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID     GEO_LON  \
# REPORTED_DATE
# 2016-05-12 16:45:00      traffic-accident    traffic-accident -104.847024
# 2016-05-12 16:45:00      traffic-accident    traffic-accident -105.049180
# 2016-05-12 16:45:00  fraud-identity-theft  white-collar-crime -104.931971
#
#                        GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2016-05-12 16:45:00  39.779596       montbello         0           1
# 2016-05-12 16:45:00  39.769296   west-highland         0           1
# 2016-05-12 16:45:00  39.717359         hilltop         1           0

# %%
crime.loc['2016-05-12']
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2016-05-12 23:51:00         criminal-mischief-other
# 2016-05-12 18:40:00               liquor-possession
# 2016-05-12 22:26:00                traffic-accident
# 2016-05-12 20:35:00                   theft-bicycle
# 2016-05-12 09:39:00          theft-of-motor-vehicle
# 2016-05-12 17:39:00                traffic-accident
# 2016-05-12 08:51:00      burglary-business-by-force
# 2016-05-12 20:13:00         criminal-mischief-other
# 2016-05-12 13:23:00                traffic-accident
# 2016-05-12 20:56:00                traffic-accident
# 2016-05-12 14:26:00                traffic-accident
# 2016-05-12 18:01:00       public-order-crimes-other
# 2016-05-12 07:17:00                traffic-accident
# 2016-05-12 18:20:00                   theft-bicycle
# 2016-05-12 16:01:00        theft-parts-from-vehicle
# 2016-05-12 20:31:00         drug-poss-paraphernalia
# 2016-05-12 08:15:00         criminal-mischief-other
# ...

# %%
crime.loc['2016-05'].shape
# Out:
# (8012, 7)

# %%
crime.loc['2016'].shape
# Out:
# (91076, 7)

# %%
crime.loc['Dec 2015'].sort_index()
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2015-12-01 00:48:00            drug-cocaine-possess
# 2015-12-01 00:48:00          theft-of-motor-vehicle
# 2015-12-01 01:00:00         criminal-mischief-other
# 2015-12-01 01:10:00                      traf-other
# 2015-12-01 01:10:00          traf-habitual-offender
# 2015-12-01 01:27:00                      traf-other
# 2015-12-01 01:44:00                       extortion
# 2015-12-01 01:44:00      weapon-carrying-prohibited
# 2015-12-01 01:44:00       weapon-carrying-concealed
# 2015-12-01 01:50:00          traf-habitual-offender
# 2015-12-01 01:50:00                      traf-other
# 2015-12-01 01:55:00                      traf-other
# 2015-12-01 02:07:00                      traf-other
# 2015-12-01 02:15:00                      traf-other
# 2015-12-01 02:38:00                      traf-other
# 2015-12-01 03:27:00                      traf-other
# 2015-12-01 04:18:00                traffic-accident
# ...

# %%
crime.loc['2016 Sep, 15'].shape
# Out:
# (252, 7)

# %%
crime.loc['21st October 2014 05'].shape
# Out:
# (4, 7)

# %%
crime.loc['2015-3-4' : '2016-01-01'].sort_index()
# Out:
#                                    OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2015-03-04 00:11:00                     assault-dv
# 2015-03-04 00:19:00                     assault-dv
# 2015-03-04 00:27:00              theft-of-services
# 2015-03-04 00:49:00   traffic-accident-hit-and-run
# 2015-03-04 01:07:00     burglary-business-no-force
# 2015-03-04 01:13:00   traffic-accident-hit-and-run
# 2015-03-04 01:20:00       prostitution-engaging-in
# 2015-03-04 01:32:00               traffic-accident
# 2015-03-04 02:02:00         agg-aslt-police-weapon
# 2015-03-04 02:28:00           disturbing-the-peace
# 2015-03-04 02:28:00                 assault-simple
# 2015-03-04 03:43:00     burglary-business-by-force
# 2015-03-04 04:26:00                 robbery-street
# 2015-03-04 05:26:00                         curfew
# 2015-03-04 05:26:00       police-false-information
# 2015-03-04 05:28:00              weapon-other-viol
# 2015-03-04 06:12:00               traffic-accident
# ...

# %%
crime.loc['2015-03-04 22': '2016-01-01 11:45:00'].sort_index()
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2015-03-04 22:25:00    traffic-accident-hit-and-run
# 2015-03-04 22:30:00                traffic-accident
# 2015-03-04 22:32:00    traffic-accident-hit-and-run
# 2015-03-04 22:33:00    traffic-accident-hit-and-run
# 2015-03-04 22:36:00         theft-unauth-use-of-ftd
# 2015-03-04 22:36:00         criminal-mischief-other
# 2015-03-04 22:42:00                      traf-other
# 2015-03-04 22:43:00                      traf-other
# 2015-03-04 22:43:00         drug-poss-paraphernalia
# 2015-03-04 22:43:00                      traf-other
# 2015-03-04 22:47:00     drug-methampetamine-possess
# 2015-03-04 22:47:00  violation-of-restraining-order
# 2015-03-04 22:55:00         criminal-mischief-other
# 2015-03-04 22:56:00                     theft-other
# 2015-03-04 22:58:00         criminal-mischief-other
# 2015-03-04 23:16:00                      traf-other
# 2015-03-04 23:26:00       public-order-crimes-other
# ...

# %%
mem_cat = crime.memory_usage().sum()
mem_obj = crime.astype({'OFFENSE_TYPE_ID' : 'object', 'OFFENSE_CATEGORY_ID' : 'object', 'NEIGHBORHOOD_ID' : 'object'}).memory_usage(deep = True).sum()
mb = 2 ** 20
round(mem_cat/ mb, 1), round(mem_obj / mb, 1)
# Out:
# (29.4, 122.7)

# %%
crime.index[:2]
# Out:
# DatetimeIndex(['2014-06-29 02:01:00', '2014-06-29 01:54:00'], dtype='datetime64[ns]', name='REPORTED_DATE', freq=None)

# %%
# %timeit crime.loc['2015-03-04': '2016-1-1']
# Out:
# 8.13 ms ± 826 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
crime_sort = crime.sort_index()
# %timeit crime.loc['2015-03-04': '2016-1-1']
# Out:
# 6.71 ms ± 65.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### DatetimeIndex와만 작동하는 메서드 사용하기

# %%
pwd = %pwd
crime = pd.read_hdf(pwd + '/crime.h5', 'crime').set_index('REPORTED_DATE')
print(type(crime.index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
crime.between_time('2:00', '5:00', include_end = False).head()
# Out:
#                                     OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00       traffic-accident-dui-duid    traffic-accident
# 2014-06-29 02:00:00            disturbing-the-peace     public-disorder
# 2014-06-29 02:18:00                          curfew     public-disorder
# 2014-06-29 04:17:00              aggravated-assault  aggravated-assault
# 2014-06-29 04:22:00  violation-of-restraining-order    all-other-crimes
#
#                         GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00 -105.000149  39.745753                        cbd
# 2014-06-29 02:00:00 -105.020719  39.706674                athmar-park
# 2014-06-29 02:18:00 -105.001552  39.769505                  sunnyside
# 2014-06-29 04:17:00 -105.018557  39.679229  college-view-south-platte
# 2014-06-29 04:22:00 -104.972447  39.739449              cheesman-park
#
#                      IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# ...

# %%
crime.at_time('5:47').head()
# Out:
#                                OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2013-11-26 05:47:00    criminal-mischief-other     public-disorder
# 2017-04-09 05:47:00  criminal-mischief-mtr-veh     public-disorder
# 2017-02-19 05:47:00    criminal-mischief-other     public-disorder
# 2017-02-16 05:47:00         aggravated-assault  aggravated-assault
# 2017-02-12 05:47:00        police-interference    all-other-crimes
#
#                         GEO_LON    GEO_LAT     NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 2013-11-26 05:47:00 -104.991476  39.751536                 cbd         1
# 2017-04-09 05:47:00 -104.959394  39.678425          university         1
# 2017-02-19 05:47:00 -104.986767  39.741336  north-capitol-hill         1
# 2017-02-16 05:47:00 -104.934029  39.732320                hale         1
# 2017-02-12 05:47:00 -104.976306  39.722644               speer         1
#
#                      IS_TRAFFIC
# REPORTED_DATE
# 2013-11-26 05:47:00           0
# ...

# %%
crime_sort = crime.sort_index()
crime_sort.first(pd.offsets.MonthBegin(6))
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# 2012-01-02 02:39:00              aggravated-assault
# 2012-01-02 03:30:00                  assault-simple
# 2012-01-02 04:07:00         criminal-mischief-other
# 2012-01-02 04:46:00                  robbery-street
# 2012-01-02 06:52:00                traffic-accident
# 2012-01-02 09:07:00                traffic-accident
# 2012-01-02 09:42:00        theft-items-from-vehicle
# 2012-01-02 10:07:00                traffic-accident
# 2012-01-02 10:21:00                robbery-business
# 2012-01-02 10:55:00    traffic-accident-hit-and-run
# 2012-01-02 11:05:00              aggravated-assault
# 2012-01-02 11:32:00        theft-parts-from-vehicle
# ...

# %%
crime_sort.first(pd.offsets.MonthEnd(6))
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# 2012-01-02 02:39:00              aggravated-assault
# 2012-01-02 03:30:00                  assault-simple
# 2012-01-02 04:07:00         criminal-mischief-other
# 2012-01-02 04:46:00                  robbery-street
# 2012-01-02 06:52:00                traffic-accident
# 2012-01-02 09:07:00                traffic-accident
# 2012-01-02 09:42:00        theft-items-from-vehicle
# 2012-01-02 10:07:00                traffic-accident
# 2012-01-02 10:21:00                robbery-business
# 2012-01-02 10:55:00    traffic-accident-hit-and-run
# 2012-01-02 11:05:00              aggravated-assault
# 2012-01-02 11:32:00        theft-parts-from-vehicle
# ...

# %%
crime_sort.first(pd.offsets.MonthBegin(6, normalize=True))
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# 2012-01-02 02:39:00              aggravated-assault
# 2012-01-02 03:30:00                  assault-simple
# 2012-01-02 04:07:00         criminal-mischief-other
# 2012-01-02 04:46:00                  robbery-street
# 2012-01-02 06:52:00                traffic-accident
# 2012-01-02 09:07:00                traffic-accident
# 2012-01-02 09:42:00        theft-items-from-vehicle
# 2012-01-02 10:07:00                traffic-accident
# 2012-01-02 10:21:00                robbery-business
# 2012-01-02 10:55:00    traffic-accident-hit-and-run
# 2012-01-02 11:05:00              aggravated-assault
# 2012-01-02 11:32:00        theft-parts-from-vehicle
# ...

# %%
crime_sort.loc[:'2012-06']
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# 2012-01-02 02:39:00              aggravated-assault
# 2012-01-02 03:30:00                  assault-simple
# 2012-01-02 04:07:00         criminal-mischief-other
# 2012-01-02 04:46:00                  robbery-street
# 2012-01-02 06:52:00                traffic-accident
# 2012-01-02 09:07:00                traffic-accident
# 2012-01-02 09:42:00        theft-items-from-vehicle
# 2012-01-02 10:07:00                traffic-accident
# 2012-01-02 10:21:00                robbery-business
# 2012-01-02 10:55:00    traffic-accident-hit-and-run
# 2012-01-02 11:05:00              aggravated-assault
# 2012-01-02 11:32:00        theft-parts-from-vehicle
# ...

# %%
crime_sort.first('5D') # 5일
crime_sort.first('5B') # 5 영업일
crime_sort.first('7W') # 7주 주의 끝은 일요일
crime_sort.first('3QS') # 3분기 시작
crime_sort.first('A') # 연말
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# 2012-01-02 02:39:00              aggravated-assault
# 2012-01-02 03:30:00                  assault-simple
# 2012-01-02 04:07:00         criminal-mischief-other
# 2012-01-02 04:46:00                  robbery-street
# 2012-01-02 06:52:00                traffic-accident
# 2012-01-02 09:07:00                traffic-accident
# 2012-01-02 09:42:00        theft-items-from-vehicle
# 2012-01-02 10:07:00                traffic-accident
# 2012-01-02 10:21:00                robbery-business
# 2012-01-02 10:55:00    traffic-accident-hit-and-run
# 2012-01-02 11:05:00              aggravated-assault
# 2012-01-02 11:32:00        theft-parts-from-vehicle
# ...

# %%
import datetime
crime.between_time(datetime.time(2,0), datetime.time(5,0), include_end=False)
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00       traffic-accident-dui-duid
# 2014-06-29 02:00:00            disturbing-the-peace
# 2014-06-29 02:18:00                          curfew
# 2014-06-29 04:17:00              aggravated-assault
# 2014-06-29 04:22:00  violation-of-restraining-order
# 2014-06-29 02:56:00       traffic-accident-dui-duid
# 2014-06-29 04:54:00                      assault-dv
# 2014-06-29 03:56:00            criminal-trespassing
# 2014-06-29 03:42:00    traffic-accident-hit-and-run
# 2013-07-05 03:48:00                      assault-dv
# 2013-07-20 04:54:00                      assault-dv
# 2014-01-16 02:25:00                      assault-dv
# 2014-03-23 04:38:00                          curfew
# 2014-05-29 03:34:00               liquor-possession
# 2014-03-02 04:02:00             drug-pcs-other-drug
# 2013-12-16 02:48:00                      traf-other
# 2013-11-16 02:27:00          traf-vehicular-assault
# ...

# %%
first_date = crime_sort.index[0]
first_date
# Out:
# Timestamp('2012-01-02 00:06:00')

# %%
first_date + pd.offsets.MonthBegin(6)
# Out:
# Timestamp('2012-07-01 00:06:00')

# %%
first_date + pd.offsets.MonthEnd(6)
# Out:
# Timestamp('2012-06-30 00:06:00')

# %%
step4 = crime_sort.first(pd.offsets.MonthEnd(6))
end_dt = crime_sort.index[0] + pd.offsets.MonthEnd(6)
step4_internal = crime_sort[:end_dt]
step4.equals(step4_internal)
# Out:
# True

# %%
dt = pd.Timestamp('2012-1-16 13:40')
dt + pd.DateOffset(months = 1)
# Out:
# Timestamp('2012-02-16 13:40:00')

# %%
do = pd.DateOffset(years = 2, month=5, days = 3, hour = 8, seconds = 10)
pd.Timestamp('2012-1-22 03:22') + do
# Out:
# Timestamp('2014-05-25 08:22:10')

# %% [markdown]
# -  DateOffsets 객체에 대한 pandas 의 문서 : http://pandas.pydata.org/pandas-docs/stable/timeseries.html#dateoffset-objects

# %% [markdown]
# ### 주간 범죄 건수 알아보기

# %%
crime_sort = pd.read_hdf(pwd+'/crime.h5', 'crime').set_index('REPORTED_DATE').sort_index()

# %%
crime_sort.resample('W')
# Out:
# DatetimeIndexResampler [freq=<Week: weekday=6>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
weekly_crimes = crime_sort.resample('W').size()
weekly_crimes.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %%
len(crime_sort.loc[:'2012-1-8'])
# Out:
# 877

# %%
len(crime_sort.loc['2012-1-9' : '2012-1-15'])
# Out:
# 1071

# %%
crime_sort.resample('W-THU').size().head()
# Out:
# REPORTED_DATE
# 2012-01-05     462
# 2012-01-12    1116
# 2012-01-19     924
# 2012-01-26    1061
# 2012-02-02     926
# Freq: W-THU, dtype: int64

# %%
weekly_crimes_gby = crime_sort.groupby(pd.Grouper(freq = 'W')).size()
weekly_crimes_gby.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %%
weekly_crimes.equals(weekly_crimes_gby)
# Out:
# True

# %%
r = crime_sort.resample('W')
resample_methods = [attr for attr in dir(r) if attr[0].islower()]
print(resample_methods)
# Out:
# ['agg', 'aggregate', 'apply', 'asfreq', 'ax', 'backfill', 'bfill', 'count', 'ffill', 'fillna', 'first', 'get_group', 'groups', 'indices', 'interpolate', 'last', 'max', 'mean', 'median', 'min', 'ndim', 'nearest', 'ngroups', 'nunique', 'obj', 'ohlc', 'pad', 'pipe', 'plot', 'prod', 'sem', 'size', 'std', 'sum', 'transform', 'var']

# %%
crime = pd.read_hdf(pwd + '/crime.h5', 'crime')
weekly_crimes2 = crime.resample('W', on  = 'REPORTED_DATE').size()
weekly_crimes2.equals(weekly_crimes)
# Out:
# True

# %%
weekly_crimes_gby2 = crime.groupby(pd.Grouper(key='REPORTED_DATE', freq = 'W')).size()
weekly_crimes_gby2.equals(weekly_crimes_gby)
# Out:
# True

# %%
weekly_crimes.plot(figsize=(16,4), title = 'ALL Denver Crimes')

# %% [markdown]
# - Resmapling에 대한 pandas 공식문서 : http://pandas.pydata.org/pandas-docs/stable/timeseries.html#resampling
# - Anchored Offsets에 대한 테이블 참고 : http://pandas.pydata.org/pandas-docs/stable/timeseries.html#anchored-offsets

# %% [markdown]
# ### 주별 범죄와 교통사고를 별도로 종합

# %%
crime_sort = pd.read_hdf(pwd+'/crime.h5', 'crime').set_index('REPORTED_DATE').sort_index()

# %%
crime_quarterly = crime_sort.resample('Q')['IS_CRIME', 'IS_TRAFFIC'].sum()
crime_quarterly.head()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-03-31         7882        4726
# 2012-06-30         9641        5255
# 2012-09-30        10566        5003
# 2012-12-31         9197        4802
# 2013-03-31         8730        4442

# %%
crime_sort.loc['2012-4-1' : '2012-6-30', ['IS_CRIME', 'IS_TRAFFIC']].sum()
# Out:
# IS_CRIME      9641
# IS_TRAFFIC    5255
# dtype: int64

# %%
crime_quarterly2 = crime_sort.groupby(pd.Grouper(freq = 'Q'))['IS_CRIME', 'IS_TRAFFIC'].sum()
crime_quarterly2.equals(crime_quarterly)
# Out:
# True

# %%
plot_kwargs = dict(figsize=(16,4), color = ['black', 'lightgrey'], title = 'Denver Crimes and Traffic Accidents')

crime_quarterly.plot(**plot_kwargs)

# %%
crime_sort.resample('Q').sum().head()
# Out:
#                     GEO_LON        GEO_LAT  IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-03-31    -1.313006e+06  496960.237747      7882        4726
# 2012-06-30    -1.547274e+06  585656.789182      9641        5255
# 2012-09-30    -1.615835e+06  611604.800384     10566        5003
# 2012-12-31    -1.458177e+06  551923.040048      9197        4802
# 2013-03-31    -1.368931e+06  518159.721947      8730        4442

# %%
crime_sort.resample('QS-MAR')['IS_CRIME', 'IS_TRAFFIC'].sum().head()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2011-12-01         5013        3198
# 2012-03-01         9260        4954
# 2012-06-01        10524        5190
# 2012-09-01         9450        4777
# 2012-12-01         9003        4652

# %%
crime_begin = crime_quarterly.iloc[0]
crime_begin
# Out:
# IS_CRIME      7882
# IS_TRAFFIC    4726
# Name: 2012-03-31 00:00:00, dtype: int64

# %%
crime_quarterly.div(crime_begin).sub(1).round(2).plot(**plot_kwargs)

# %% [markdown]
# ### 범죄를 주별과 연도로 측정

# %%
crime_sort = pd.read_hdf(pwd+'/crime.h5', 'crime')
crime_sort.head()
# Out:
#               OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID       REPORTED_DATE  \
# 0   traffic-accident-dui-duid    traffic-accident 2014-06-29 02:01:00
# 1  vehicular-eluding-no-chase    all-other-crimes 2014-06-29 01:54:00
# 2        disturbing-the-peace     public-disorder 2014-06-29 02:00:00
# 3                      curfew     public-disorder 2014-06-29 02:18:00
# 4          aggravated-assault  aggravated-assault 2014-06-29 04:17:00
#
#       GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0 -105.000149  39.745753                        cbd         0           1
# 1 -104.884660  39.738702                east-colfax         1           0
# 2 -105.020719  39.706674                athmar-park         1           0
# 3 -105.001552  39.769505                  sunnyside         1           0
# 4 -105.018557  39.679229  college-view-south-platte         1           0

# %%
wd_counts = crime['REPORTED_DATE'].dt.weekday_name.value_counts()
wd_counts
# Out:
# Monday       70024
# Friday       69621
# Wednesday    69538
# Thursday     69287
# Tuesday      68394
# Saturday     58834
# Sunday       55213
# Name: REPORTED_DATE, dtype: int64

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
title = 'Denver Crimes and Traffic Accidents per Weekday'
wd_counts.reindex(days).plot(kind = 'barh', title = title)

# %%
title = 'Denver Crimes and Traffic Accidents per Year'
crime['REPORTED_DATE'].dt.year.value_counts().sort_index().plot(kind = 'barh', title=  title)

# %%
weekday = crime['REPORTED_DATE'].dt.weekday_name
year = crime['REPORTED_DATE'].dt.year

# %%
crime_wd_y = crime.groupby([year.rename('YEAR'), weekday.rename('WEEKDAY')]).size() # groupby breaks when using duplicated level names >> rename 처리
crime_wd_y.head(10)
# Out:
# YEAR  WEEKDAY
# 2012  Friday        8549
#       Monday        8786
#       Saturday      7442
#       Sunday        7189
#       Thursday      8440
#       Tuesday       8191
#       Wednesday     8440
# 2013  Friday       10380
#       Monday       10627
#       Saturday      8875
# dtype: int64

# %%
crime_table = crime_wd_y.rename_axis(['Year', 'Weekday']).unstack('Weekday')
crime_table
# Out:
# Weekday  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# Year
# 2012       8549    8786      7442    7189      8440     8191       8440
# 2013      10380   10627      8875    8444     10431    10416      10354
# 2014      12683   12813     10950   10278     12309    12440      12948
# 2015      13273   13452     11586   10624     13512    13381      13320
# 2016      14059   13708     11467   10554     14050    13338      13900
# 2017      10677   10638      8514    8124     10545    10628      10576

# %%
criteria = crime['REPORTED_DATE'].dt.year == 2017
crime.loc[criteria, 'REPORTED_DATE'].dt.dayofyear.max()
# Out:
# 272

# %%
round(272 / 365, 3)
# Out:
# 0.745

# %%
crime_pct = crime['REPORTED_DATE'].dt.dayofyear.le(272).groupby(year).mean().round(3)
crime_pct
# Out:
# REPORTED_DATE
# 2012    0.748
# 2013    0.725
# 2014    0.751
# 2015    0.748
# 2016    0.752
# 2017    1.000
# Name: REPORTED_DATE, dtype: float64

# %%
crime_pct.loc[2012:2016].median()
# Out:
# 0.748

# %%
crime_table.loc[2017] = crime_table.loc[2017].div(.748).astype('int')
crime_table = crime_table.reindex(columns=days)
crime_table
# Out:
# Weekday  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# Year
# 2012       8786     8191       8440      8440    8549      7442    7189
# 2013      10627    10416      10354     10431   10380      8875    8444
# 2014      12813    12440      12948     12309   12683     10950   10278
# 2015      13452    13381      13320     13512   13273     11586   10624
# 2016      13708    13338      13900     14050   14059     11467   10554
# 2017      14221    14208      14139     14097   14274     11382   10860

# %%
import seaborn as sns
sns.heatmap(crime_table, cmap = 'Greys')

# %%
denver_pop = pd.read_csv(pwd + '/denver_pop.csv', index_col = 'Year')
denver_pop
# Out:
#       Population
# Year
# 2017      705000
# 2016      693000
# 2015      680000
# 2014      662000
# 2013      647000
# 2012      634000

# %%
den_100k= denver_pop.div(100000).squeeze()
crime_table2 = crime_table.div(den_100k, axis = 'index').astype('int')
crime_table2
# Out:
# Weekday  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# Year
# 2012       1385     1291       1331      1331    1348      1173    1133
# 2013       1642     1609       1600      1612    1604      1371    1305
# 2014       1935     1879       1955      1859    1915      1654    1552
# 2015       1978     1967       1958      1987    1951      1703    1562
# 2016       1978     1924       2005      2027    2028      1654    1522
# 2017       2017     2015       2005      1999    2024      1614    1540

# %%
sns.heatmap(crime_table2, cmap = 'Greys')

# %%
wd_counts.loc[days]
# Out:
# Monday       70024
# Tuesday      68394
# Wednesday    69538
# Thursday     69287
# Friday       69621
# Saturday     58834
# Sunday       55213
# Name: REPORTED_DATE, dtype: int64

# %%
ADJ_2017 = .748

def count_crime(df, offense_cat):
    df = df[df['OFFENSE_CATEGORY_ID'] == offense_cat]
    weekday = df['REPORTED_DATE'].dt.weekday_name
    year = df['REPORTED_DATE'].dt.year
    
    ct = df.groupby([year.rename('YEAR'), weekday.rename('WEEKDAY')]).size().unstack()
    ct.loc[2017] = ct.loc[2017].div(ADJ_2017).astype('int')
    
    pop = pd.read_csv(pwd + '/denver_pop.csv', index_col = 'Year')
    pop = pop.squeeze().div(100000)
    
    ct = ct.div(pop, axis = 0).astype('int')
    ct = ct.reindex(columns = days)
    sns.heatmap(ct, cmap = 'Greys')
    
    return ct

count_crime(crime, 'auto-theft')
# Out:
# WEEKDAY  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 2012         95       72         72        76      71        78      76
# 2013         85       74         74        69      65        68      67
# 2014         94       76         72        70      76        67      67
# 2015        108      102         89       101      92        85      78
# 2016        119      102        100        99      97        86      85
# 2017        114      118        111       106     111        91     102

# %% [markdown]
# - reindex 메서드에 대한 pandas의 공식 문서 : https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reindex.html
# - heatmap 함수에 대한 seaborn의 공식 문서 : https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# ### DatetimeIndex에서 익명 함수를 사용한 그룹화

# %%
crime_sort = pd.read_hdf(pwd + '/crime.h5', 'crime').set_index('REPORTED_DATE').sort_index()
common_attrs = set(dir(crime_sort.index)) & set(dir(pd.Timestamp))
print([attr for attr in common_attrs if attr[0] != '_'])
# Out:
# ['min', 'year', 'strftime', 'month', 'tz_convert', 'weekofyear', 'microsecond', 'is_month_start', 'to_julian_date', 'day', 'dayofyear', 'floor', 'second', 'ceil', 'is_quarter_start', 'is_year_end', 'is_year_start', 'is_quarter_end', 'tz_localize', 'is_leap_year', 'minute', 'daysinmonth', 'time', 'quarter', 'weekday_name', 'hour', 'normalize', 'round', 'days_in_month', 'is_month_end', 'date', 'weekday', 'freq', 'day_name', 'month_name', 'resolution', 'tz', 'freqstr', 'tzinfo', 'week', 'nanosecond', 'to_period', 'dayofweek', 'to_pydatetime', 'max']

# %%
crime_sort.index.weekday_name.value_counts()
# Out:
# Monday       70024
# Friday       69621
# Wednesday    69538
# Thursday     69287
# Tuesday      68394
# Saturday     58834
# Sunday       55213
# Name: REPORTED_DATE, dtype: int64

# %%
crime_sort.groupby(lambda x: x.weekday_name)['IS_CRIME', 'IS_TRAFFIC'].sum()
# Out:
#            IS_CRIME  IS_TRAFFIC
# Friday        48833       20814
# Monday        52158       17895
# Saturday      43363       15516
# Sunday        42315       12968
# Thursday      49470       19845
# Tuesday       49658       18755
# Wednesday     50054       19508

# %%
funcs = [lambda x: x.round('2h').hour, lambda x: x.year]
cr_group = crime_sort.groupby(funcs)['IS_CRIME', 'IS_TRAFFIC'].sum()
cr_final = cr_group.unstack()
cr_final.style.highlight_max(color='lightgrey')
# Out:
# <style  type="text/css" >
#     #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row6_col0 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row8_col1 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row8_col2 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row8_col3 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row8_col4 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row8_col5 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row8_col11 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row9_col6 {
#             background-color:  lightgrey;
#         }    #T_8ecacfdc_8e77_11e8_940d_f45c898bd271row9_col7 {
# ...

# %%
cr_final.xs('IS_TRAFFIC', axis = 'columns', level=0).head()
# Out:
#    2012  2013  2014  2015  2016  2017
# 0   919   792   978  1136   980   782
# 2   718   652   779   773   718   537
# 4   399   378   424   471   464   313
# 6   411   399   479   494   593   462
# 8  1957  1955  2210  2331  2372  1828

# %%
cr_final.xs(2016, axis = 'columns', level=1).head()
# Out:
#    IS_CRIME  IS_TRAFFIC
# 0      5377         980
# 2      4091         718
# 4      3044         464
# 6      2108         593
# 8      4488        2372

# %% [markdown]
# - 교집합 메서드 xs 에 대한 pandas 문서 : https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html

# %% [markdown]
# ### Timestamp와 다른 열을 이용한 그룹화

# %%
employee = pd.read_csv((pwd + '/employee.csv'), parse_dates = ['JOB_DATE', 'HIRE_DATE'], index_col = 'HIRE_DATE' )
employee.head()
# Out:
#             UNIQUE_ID               POSITION_TITLE  \
# HIRE_DATE
# 2006-06-12          0  ASSISTANT DIRECTOR (EX LVL)
# 2000-07-19          1            LIBRARY ASSISTANT
# 2015-02-03          2               POLICE OFFICER
# 1982-02-08          3            ENGINEER/OPERATOR
# 1989-06-19          4                  ELECTRICIAN
#
#                                DEPARTMENT  BASE_SALARY             RACE  \
# HIRE_DATE
# 2006-06-12    Municipal Courts Department     121862.0  Hispanic/Latino
# 2000-07-19                        Library      26125.0  Hispanic/Latino
# 2015-02-03  Houston Police Department-HPD      45279.0            White
# 1982-02-08  Houston Fire Department (HFD)      63166.0            White
# 1989-06-19    General Services Department      56347.0            White
#
#            EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS   JOB_DATE
# HIRE_DATE
# 2006-06-12       Full Time  Female            Active 2012-10-13
# ...

# %%
employee.groupby('GENDER')['BASE_SALARY'].mean().round(-2)
# Out:
# GENDER
# Female    52200.0
# Male      57400.0
# Name: BASE_SALARY, dtype: float64

# %%
employee.resample('10AS')['BASE_SALARY'].mean().round(-2)
# Out:
# HIRE_DATE
# 1958-01-01     81200.0
# 1968-01-01    106500.0
# 1978-01-01     69600.0
# 1988-01-01     62300.0
# 1998-01-01     58200.0
# 2008-01-01     47200.0
# 2018-01-01         NaN
# Name: BASE_SALARY, dtype: float64

# %%
sal_avg = employee.groupby('GENDER').resample('10AS')['BASE_SALARY'].mean().round(-2)
sal_avg
# Out:
# GENDER  HIRE_DATE
# Female  1975-01-01     51600.0
#         1985-01-01     57600.0
#         1995-01-01     55500.0
#         2005-01-01     51700.0
#         2015-01-01     38600.0
#         2025-01-01         NaN
# Male    1958-01-01     81200.0
#         1968-01-01    106500.0
#         1978-01-01     72300.0
#         1988-01-01     64600.0
#         1998-01-01     59700.0
#         2008-01-01     47200.0
#         2018-01-01         NaN
# Name: BASE_SALARY, dtype: float64

# %%
sal_avg.unstack('GENDER')
# Out:
# GENDER       Female      Male
# HIRE_DATE
# 1958-01-01      NaN   81200.0
# 1968-01-01      NaN  106500.0
# 1975-01-01  51600.0       NaN
# 1978-01-01      NaN   72300.0
# 1985-01-01  57600.0       NaN
# 1988-01-01      NaN   64600.0
# 1995-01-01  55500.0       NaN
# 1998-01-01      NaN   59700.0
# 2005-01-01  51700.0       NaN
# 2008-01-01      NaN   47200.0
# 2015-01-01  38600.0       NaN
# 2018-01-01      NaN       NaN
# 2025-01-01      NaN       NaN

# %%
employee[employee['GENDER']  == 'Male'].index.min()
# Out:
# Timestamp('1958-12-29 00:00:00')

# %%
employee[employee['GENDER']  == 'Female'].index.min()
# Out:
# Timestamp('1975-06-09 00:00:00')

# %%
sal_avg2 = employee.groupby(['GENDER', pd.Grouper(freq = '10AS')])['BASE_SALARY'].mean().round(-2)
sal_avg2
# Out:
# GENDER  HIRE_DATE
# Female  1968-01-01         NaN
#         1978-01-01     57100.0
#         1988-01-01     57100.0
#         1998-01-01     54700.0
#         2008-01-01     47300.0
# Male    1958-01-01     81200.0
#         1968-01-01    106500.0
#         1978-01-01     72300.0
#         1988-01-01     64600.0
#         1998-01-01     59700.0
#         2008-01-01     47200.0
# Name: BASE_SALARY, dtype: float64

# %%
sal_final = sal_avg2.unstack('GENDER')
sal_final
# Out:
# GENDER       Female      Male
# HIRE_DATE
# 1968-01-01      NaN  106500.0
# 1978-01-01  57100.0   72300.0
# 1988-01-01  57100.0   64600.0
# 1998-01-01  54700.0   59700.0
# 2008-01-01  47300.0   47200.0
# 1958-01-01      NaN   81200.0

# %%
'resample' in dir(employee.groupby('GENDER'))
# Out:
# True

# %%
'groupby' in dir(employee.resample('10AS'))
# Out:
# False

# %%
years = sal_final.index.year
years_right = years + 9
sal_final.index = years.astype(str) + '-' + years_right.astype(str)
sal_final
# Out:
# GENDER      Female      Male
# 1968-1977      NaN  106500.0
# 1978-1987  57100.0   72300.0
# 1988-1997  57100.0   64600.0
# 1998-2007  54700.0   59700.0
# 2008-2017  47300.0   47200.0
# 1958-1967      NaN   81200.0

# %%
cuts = pd.cut(employee.index.year, bins = 5, precision=0)
cuts.categories.values
# Out:
# array([Interval(1958.0, 1970.0, closed='right'),
#        Interval(1970.0, 1981.0, closed='right'),
#        Interval(1981.0, 1993.0, closed='right'),
#        Interval(1993.0, 2004.0, closed='right'),
#        Interval(2004.0, 2016.0, closed='right')], dtype=object)

# %%
employee.groupby([cuts, 'GENDER'])['BASE_SALARY'].mean().unstack('GENDER').round(-2)
# Out:
# GENDER             Female     Male
# (1958.0, 1970.0]      NaN  85400.0
# (1970.0, 1981.0]  54400.0  72700.0
# (1981.0, 1993.0]  55700.0  69300.0
# (1993.0, 2004.0]  56500.0  62300.0
# (2004.0, 2016.0]  49100.0  49800.0

# %% [markdown]
# ### merge_asof를 사용해 범죄율이 20% 낮은 마지막 시기 찾기

# %%
crime_sort = pd.read_hdf(pwd + '/crime.h5', 'crime').set_index('REPORTED_DATE').sort_index()

# %%
crime_sort.index.max()
# Out:
# Timestamp('2017-09-29 06:16:00')

# %%
crime_sort = crime_sort[:'2017-8']
crime_sort.index.max()
# Out:
# Timestamp('2017-08-31 23:52:00')

# %%
all_data = crime_sort.groupby([pd.Grouper(freq='M'), 'OFFENSE_CATEGORY_ID']).size()
all_data.head()
# Out:
# REPORTED_DATE  OFFENSE_CATEGORY_ID
# 2012-01-31     aggravated-assault     113
#                all-other-crimes       124
#                arson                    5
#                auto-theft             275
#                burglary               343
# dtype: int64

# %%
all_data = all_data.sort_values().reset_index(name = 'Total')
all_data.head()
# Out:
#   REPORTED_DATE OFFENSE_CATEGORY_ID  Total
# 0    2014-12-31              murder      1
# 1    2013-01-31               arson      1
# 2    2016-05-31              murder      1
# 3    2012-12-31              murder      1
# 4    2016-12-31              murder      1

# %%
goal = all_data[all_data['REPORTED_DATE'] == '2017-8-31'].reset_index(drop = True)
goal['Total_Goal'] = goal['Total'].mul(.8).astype(int)
goal.head()
# Out:
#   REPORTED_DATE OFFENSE_CATEGORY_ID  Total  Total_Goal
# 0    2017-08-31              murder      7           5
# 1    2017-08-31               arson      7           5
# 2    2017-08-31      sexual-assault     57          45
# 3    2017-08-31             robbery    108          86
# 4    2017-08-31  white-collar-crime    138         110

# %%
pd.merge_asof(goal, all_data, left_on = 'Total_Goal', right_on = 'Total', by = 'OFFENSE_CATEGORY_ID', suffixes=('_Current', '_Last'))
# Out:
#    REPORTED_DATE_Current           OFFENSE_CATEGORY_ID  Total_Current  \
# 0             2017-08-31                        murder              7
# 1             2017-08-31                         arson              7
# 2             2017-08-31                sexual-assault             57
# 3             2017-08-31                       robbery            108
# 4             2017-08-31            white-collar-crime            138
# 5             2017-08-31            aggravated-assault            195
# 6             2017-08-31  other-crimes-against-persons            376
# 7             2017-08-31                      burglary            432
# 8             2017-08-31                    auto-theft            599
# 9             2017-08-31                  drug-alcohol            636
# 10            2017-08-31      theft-from-motor-vehicle            675
# 11            2017-08-31                       larceny            877
# ...

# %%
pd.Period(year= 2012, month = 5, day = 17, hour = 14, minute = 20, freq = 'T')
# Out:
# Period('2012-05-17 14:20', 'T')

# %%
ad_period = crime_sort.groupby([lambda x : x.to_period('M'), 'OFFENSE_CATEGORY_ID']).size()
ad_period = ad_period.sort_values().reset_index(name = 'Total').rename(columns = {'level_0' : 'REPORTED_DATE'})
ad_period.head()
# Out:
#   REPORTED_DATE OFFENSE_CATEGORY_ID  Total
# 0       2014-12              murder      1
# 1       2013-01               arson      1
# 2       2016-05              murder      1
# 3       2012-12              murder      1
# 4       2016-12              murder      1

# %%
cols = ['OFFENSE_CATEGORY_ID', 'Total']
all_data[cols].equals(ad_period[cols])
# Out:
# True

# %%
aug_2018 = pd.Period('2017-8', freq = 'M')
goal_period = ad_period[ad_period['REPORTED_DATE'] == aug_2018].reset_index(drop = True)
goal_period['Total_Goal'] = goal_period['Total'].mul(.8).astype(int)
pd.merge_asof(goal_period, ad_period, left_on= 'Total_Goal', right_on = 'Total', by = 'OFFENSE_CATEGORY_ID', suffixes=('_Current', '_Last')).head()
# Out:
#   REPORTED_DATE_Current OFFENSE_CATEGORY_ID  Total_Current  Total_Goal  \
# 0               2017-08              murder              7           5
# 1               2017-08               arson              7           5
# 2               2017-08      sexual-assault             57          45
# 3               2017-08             robbery            108          86
# 4               2017-08  white-collar-crime            138         110
#
#   REPORTED_DATE_Last  Total_Last
# 0            2017-01           5
# 1            2012-01           5
# 2            2013-01          45
# 3            2015-03          86
# 4            2016-10         110
