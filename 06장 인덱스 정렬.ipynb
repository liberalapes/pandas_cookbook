# %% [markdown]
# # Pandas Cookbook

# %% [markdown]
# ## 6장. 인덱스 정렬

# %% [markdown]
# ### 소개

# %% [markdown]
# https://github.com/PacktPublishing/Pandas-Cookbook/tree/master/data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 인덱스 객체 관찰

# %%
colleges = pd.read_csv('/Users/chosikc/Sites/PandasCookbook/college.csv')
columns = colleges.columns
columns

# 열 인덱스를 변수에 대힙하고 값을 출력한다.
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
columns.values

# .values 를 사용하여 Numpy 배열로 표시해본다.
# Out:
# array(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY',
#        'RELAFFIL', 'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS',
#        'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN',
#        'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF',
#        'CURROPER', 'PCTPELL', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10',
#        'GRAD_DEBT_MDN_SUPP'], dtype=object)

# %%
columns[5]
# 인덱스의 위치로 특정 값을 소환한다.
# Out:
# 'WOMENONLY'

# %%
columns[[1,8,10]]
# Out:
# Index(['CITY', 'SATMTMID', 'UGDS'], dtype='object')

# %%
columns[-7:-4]
# Out:
# Index(['PPTUG_EF', 'CURROPER', 'PCTPELL'], dtype='object')

# %%
columns.min(), columns.max(), columns.isnull().sum()
# Out:
# ('CITY', 'WOMENONLY', 0)

# %%
columns + '_A'
# 일괄로 '_A' 를 붙일수도 있다.
# Out:
# Index(['INSTNM_A', 'CITY_A', 'STABBR_A', 'HBCU_A', 'MENONLY_A', 'WOMENONLY_A',
#        'RELAFFIL_A', 'SATVRMID_A', 'SATMTMID_A', 'DISTANCEONLY_A', 'UGDS_A',
#        'UGDS_WHITE_A', 'UGDS_BLACK_A', 'UGDS_HISP_A', 'UGDS_ASIAN_A',
#        'UGDS_AIAN_A', 'UGDS_NHPI_A', 'UGDS_2MOR_A', 'UGDS_NRA_A',
#        'UGDS_UNKN_A', 'PPTUG_EF_A', 'CURROPER_A', 'PCTPELL_A', 'PCTFLOAN_A',
#        'UG25ABV_A', 'MD_EARN_WNE_P10_A', 'GRAD_DEBT_MDN_SUPP_A'],
#       dtype='object')

# %%
columns > 'G'
# index 를 비교하여 불리언 값으로 표시한다.
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True])

# %%
columns[1] = 'city'
#TypeError: Index does not support mutable operations
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f9345cf1bcbf> in <module>()
# ----> 1 columns[1] = 'city'
#       2 #TypeError: Index does not support mutable operations
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    2048
#    2049     def __setitem__(self, key, value):
# -> 2050         raise TypeError("Index does not support mutable operations")
#    2051
#    2052     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
c1 = columns[:4]
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
c2 = columns[2:6]
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY', 'WOMENONLY'], dtype='object')

# %%
c1.union(c2) # or 'c1 | c2'
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR', 'WOMENONLY'], dtype='object')

# %%
c1.symmetric_difference(c2) # 'c1 ^ c2'
# Out:
# Index(['CITY', 'INSTNM', 'MENONLY', 'WOMENONLY'], dtype='object')

# %% [markdown]
# - 인덱스는 중복을 허용하는데, 어떤 인덱스든 일단 중복이 되면, 구현상에 해시값을 사용하지 못하게 되므로 객체 적근이 훨씬 느려진다.

# %% [markdown]
# - index에 대한 pandas의 공식문서 : https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.html

# %% [markdown]
# ### 카디션 곱 생성

# %%
s1 = pd.Series(index=list('aaab'), data=np.arange(4))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# dtype: int64

# %%
s2 = pd.Series(index=list('cababb'), data=np.arange(6))
s2
# Out:
# c    0
# a    1
# b    2
# a    3
# b    4
# b    5
# dtype: int64

# %%
s1 + s2 
# 두 Series를 더해 카티션 곱을 생성한다.
# Out:
# a    1.0
# a    3.0
# a    2.0
# a    4.0
# a    3.0
# a    5.0
# b    5.0
# b    7.0
# b    8.0
# c    NaN
# dtype: float64

# %% [markdown]
# - 임의의 두 집합, A와 B에 대해 x∈A, y∈B인 모든 순서쌍 (x, y)로 이루어진 집합을 A와 B의 데카르트곱이라 하고, A×B로 표현한다.
# - 데카르트곱(Descartes product)은 카티션곱(Cartesian product)이라고도 부른다.

# %%
s1 = pd.Series(index=list('aaabb'), data=np.arange(5))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# b    4
# dtype: int64

# %%
s2 = pd.Series(index=list('aaabb'), data=np.arange(5))
s2
# Out:
# a    0
# a    1
# a    2
# b    3
# b    4
# dtype: int64

# %%
s1 + s2
# Out:
# a    0
# a    2
# a    4
# b    6
# b    8
# dtype: int64

# %%
s1 = pd.Series(index=list('aaabb'), data=np.arange(5))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# b    4
# dtype: int64

# %%
s2 = pd.Series(index=list('bbaaa'), data=np.arange(5))
s2
# Out:
# b    0
# b    1
# a    2
# a    3
# a    4
# dtype: int64

# %%
s1 + s2
# Out:
# a    2
# a    3
# a    4
# a    3
# a    4
# a    5
# a    4
# a    5
# a    6
# b    3
# b    4
# b    4
# b    5
# dtype: int64

# %% [markdown]
# ### 인덱스 폭발

# %%
pwd = %pwd
pwd
# Out:
# '/Users/chosikc/Sites/PandasCookbook'

# %%
employee = pd.read_csv(pwd+'/employee.csv', index_col='RACE')
employee.head()

# RACE를 index로 설정한다.
# Out:
#                  UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino          0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino          1            LIBRARY ASSISTANT
# White                    2               POLICE OFFICER
# White                    3            ENGINEER/OPERATOR
# White                    4                  ELECTRICIAN
#
#                                     DEPARTMENT  BASE_SALARY EMPLOYMENT_TYPE  \
# RACE
# Hispanic/Latino    Municipal Courts Department     121862.0       Full Time
# Hispanic/Latino                        Library      26125.0       Full Time
# White            Houston Police Department-HPD      45279.0       Full Time
# White            Houston Fire Department (HFD)      63166.0       Full Time
# White              General Services Department      56347.0       Full Time
#
#                  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# RACE
# Hispanic/Latino  Female            Active  2006-06-12  2012-10-13
# ...

# %%
salary1 = employee['BASE_SALARY']
salary2 = employee['BASE_SALARY']
salary1 is salary2
# Out:
# True

# %%
salary1 = employee['BASE_SALARY'].copy()
salary2 = employee['BASE_SALARY'].copy()
salary1 is salary2
# Out:
# False

# %%
salary1 = salary1.sort_index()
salary1.head()
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
# Name: BASE_SALARY, dtype: float64

# %%
salary2.head()
# Out:
# RACE
# Hispanic/Latino    121862.0
# Hispanic/Latino     26125.0
# White               45279.0
# White               63166.0
# White               56347.0
# Name: BASE_SALARY, dtype: float64

# %%
salary_add = salary1 + salary2
salary_add.head()
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
# Name: BASE_SALARY, dtype: float64

# %%
salary_add1 = salary1 + salary1
len(salary1), len(salary2), len(salary_add), len(salary_add1)
# Out:
# (2000, 2000, 1175424, 2000)

# %%
index_vc = salary1.index.value_counts(dropna = False)
index_vc
# Out:
# Black or African American            700
# White                                665
# Hispanic/Latino                      480
# Asian/Pacific Islander               107
# NaN                                   35
# American Indian or Alaskan Native     11
# Others                                 2
# Name: RACE, dtype: int64

# %%
index_vc.pow(2).sum()

# %% [markdown]
# ### 서로 다른 인덱스에 값 채우기

# %%
baseball_14 = pd.read_csv('https://github.com/PacktPublishing/Pandas-Cookbook/raw/master/data/baseball14.csv', index_col = 'playerID')
baseball_15 = pd.read_csv('https://github.com/PacktPublishing/Pandas-Cookbook/raw/master/data/baseball15.csv', index_col = 'playerID')
baseball_16 = pd.read_csv('https://github.com/PacktPublishing/Pandas-Cookbook/raw/master/data/baseball16.csv', index_col = 'playerID')

# %%
baseball_14.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...    RBI  \
# playerID                                                         ...
# altuvjo01    2014      1    HOU   AL  158  660  85  225  47   3  ...   59.0
# cartech02    2014      1    HOU   AL  145  507  68  115  21   1  ...   88.0
# castrja01    2014      1    HOU   AL  126  465  43  103  21   2  ...   56.0
# corpoca01    2014      1    HOU   AL   55  170  22   40   6   0  ...   19.0
# dominma01    2014      1    HOU   AL  157  564  51  121  17   0  ...   57.0
#
#              SB   CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  56.0  9.0  36   53.0  7.0  5.0  1.0  5.0  20.0
# cartech02   5.0  2.0  56  182.0  6.0  5.0  0.0  4.0  12.0
# castrja01   1.0  0.0  34  151.0  1.0  9.0  1.0  3.0  11.0
# corpoca01   0.0  0.0  14   37.0  0.0  3.0  1.0  2.0   3.0
# dominma01   0.0  1.0  29  125.0  2.0  5.0  2.0  7.0  23.0
#
# [5 rows x 21 columns]

# %%
baseball_14.index.difference(baseball_15.index)
# Out:
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01', 'guzmaje01',
#        'hoeslj01', 'krausma01', 'preslal01', 'singljo02'],
#       dtype='object', name='playerID')

# %%
baseball_14.index.difference(baseball_16.index)
# Out:
# Index(['cartech02', 'corpoca01', 'dominma01', 'fowlede01', 'grossro01',
#        'guzmaje01', 'hoeslj01', 'krausma01', 'preslal01', 'singljo02',
#        'villajo01'],
#       dtype='object', name='playerID')

# %%
hits_14 = baseball_14['H']
hits_15 = baseball_15['H']
hits_16 = baseball_16['H']
hits_14.head()
# Out:
# playerID
# altuvjo01    225
# cartech02    115
# castrja01    103
# corpoca01     40
# dominma01    121
# Name: H, dtype: int64

# %%
(hits_14 + hits_15).head()
# 덧셈 연산자를 사용하여 두 Series 를 더해본다.
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01      NaN
# corpoca01      NaN
# Name: H, dtype: float64

# %%
hits_14.add(hits_15, fill_value=0).head()
# congeha01과 corpoca01 는 NaN이 발생했다.
# add 메서드와 fill_value 매개변수를 사용하여 누락값을 피해본다.
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01     46.0
# corpoca01     40.0
# Name: H, dtype: float64

# %%
hits_total = hits_14.add(hits_15, fill_value=0).add(hits_16, fill_value = 0)
hits_total.head()
# Out:
# playerID
# altuvjo01    641.0
# bregmal01     53.0
# cartech02    193.0
# castrja01    243.0
# congeha01     46.0
# Name: H, dtype: float64

# %%
hits_total.hasnans
# Out:
# False

# %%
s = pd.Series(index = ['a','b','c','d'], data = [np.nan, 3, np.nan, 1])
s
# Out:
# a    NaN
# b    3.0
# c    NaN
# d    1.0
# dtype: float64

# %%
s1 = pd.Series(index = ['a','b','c'], data = [np.nan, 6, 10])
s1
# Out:
# a     NaN
# b     6.0
# c    10.0
# dtype: float64

# %%
s.add(s1, fill_value=5)
# Out:
# a     NaN
# b     9.0
# c    15.0
# d     6.0
# dtype: float64

# %%
df_14 =  baseball_14[['G','AB','R','H']]
df_14.head()
# Out:
#              G   AB   R    H
# playerID
# altuvjo01  158  660  85  225
# cartech02  145  507  68  115
# castrja01  126  465  43  103
# corpoca01   55  170  22   40
# dominma01  157  564  51  121

# %%
df_15 =  baseball_15[['AB','R','H','HR']]
df_15.head()
# Out:
#             AB   R    H  HR
# playerID
# altuvjo01  638  86  200  15
# cartech02  391  50   78  24
# castrja01  337  38   71  11
# congeha01  201  25   46  11
# correca01  387  52  108  22

# %%
(df_14 + df_15).head(10).style.highlight_null('yellow')
# Out:
# <style  type="text/css" >
#     #T_2edd5746_8375_11e8_b749_f45c898bd271row0_col1 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row0_col3 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row1_col1 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row1_col3 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row2_col1 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row2_col3 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row3_col0 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row3_col1 {
#             background-color:  yellow;
#         }    #T_2edd5746_8375_11e8_b749_f45c898bd271row3_col2 {
#             background-color:  yellow;
# ...

# %%
df_14.add(df_15, fill_value=0).head(10).style.highlight_null('yellow')
# Out:
# <style  type="text/css" >
#     #T_30947e48_8375_11e8_941a_f45c898bd271row3_col1 {
#             background-color:  yellow;
#         }    #T_30947e48_8375_11e8_941a_f45c898bd271row4_col3 {
#             background-color:  yellow;
#         }    #T_30947e48_8375_11e8_941a_f45c898bd271row5_col1 {
#             background-color:  yellow;
#         }    #T_30947e48_8375_11e8_941a_f45c898bd271row6_col3 {
#             background-color:  yellow;
#         }    #T_30947e48_8375_11e8_941a_f45c898bd271row7_col3 {
#             background-color:  yellow;
#         }    #T_30947e48_8375_11e8_941a_f45c898bd271row8_col1 {
#             background-color:  yellow;
#         }    #T_30947e48_8375_11e8_941a_f45c898bd271row9_col1 {
#             background-color:  yellow;
#         }</style>
# <table id="T_30947e48_8375_11e8_941a_f45c898bd271" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >AB</th>
# ...

# %% [markdown]
# ### 다른 DataFrames의 열 추가

# %%
pwd = %pwd
employee = pd.read_csv(pwd+'/employee.csv')

# %%
dept_sal = employee[['DEPARTMENT', 'BASE_SALARY']]
dept_sal.head()
# employee 에서 'DEPARTMENT', 'BASE_SALARY' 만 뽑아서 새로운 DataFrame 에 넣는다.
# Out:
#                       DEPARTMENT  BASE_SALARY
# 0    Municipal Courts Department     121862.0
# 1                        Library      26125.0
# 2  Houston Police Department-HPD      45279.0
# 3  Houston Fire Department (HFD)      63166.0
# 4    General Services Department      56347.0

# %%
dept_sal = dept_sal.sort_values(['DEPARTMENT', 'BASE_SALARY'], ascending=[True, False])
# DataFrame 에 각 부서별 급여에 따라 정렬한다.
dept_sal.head()
# Out:
#                       DEPARTMENT  BASE_SALARY
# 1494  Admn. & Regulatory Affairs     140416.0
# 237   Admn. & Regulatory Affairs     130416.0
# 1679  Admn. & Regulatory Affairs     103776.0
# 988   Admn. & Regulatory Affairs      72741.0
# 693   Admn. & Regulatory Affairs      66825.0

# %%
max_dept_sal = dept_sal.drop_duplicates(subset='DEPARTMENT')
max_dept_sal.head()
# drop_duplicates 을 사용하여 DEPARTMENT의 첫 행만 유지한다.
# Out:
#                         DEPARTMENT  BASE_SALARY
# 1494    Admn. & Regulatory Affairs     140416.0
# 149       City Controller's Office      64251.0
# 236                   City Council     100000.0
# 647   Convention and Entertainment      38397.0
# 1500   Dept of Neighborhoods (DON)      89221.0

# %%
max_dept_sal = max_dept_sal.set_index('DEPARTMENT')
employee = employee.set_index('DEPARTMENT')
# index 를 DEPARTMENT 열로 설정한다.

# %%
employee['MAX_SEPT_SALARY'] = max_dept_sal['BASE_SALARY']
employee.head()

# 인덱스는 서로 매칭되는 값을 가지므로 employee DataFrame 에 새로운 열을 추가할 수 있다.
# Out:
#                                UNIQUE_ID               POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department            0  ASSISTANT DIRECTOR (EX LVL)
# Library                                1            LIBRARY ASSISTANT
# Houston Police Department-HPD          2               POLICE OFFICER
# Houston Fire Department (HFD)          3            ENGINEER/OPERATOR
# General Services Department            4                  ELECTRICIAN
#
#                                BASE_SALARY             RACE EMPLOYMENT_TYPE  \
# DEPARTMENT
# Municipal Courts Department       121862.0  Hispanic/Latino       Full Time
# Library                            26125.0  Hispanic/Latino       Full Time
# Houston Police Department-HPD      45279.0            White       Full Time
# Houston Fire Department (HFD)      63166.0            White       Full Time
# General Services Department        56347.0            White       Full Time
#
# ...

# %%
employee.query('BASE_SALARY < MAX_SEPT_SALARY').head()
# Out:
#                                UNIQUE_ID         POSITION_TITLE  BASE_SALARY  \
# DEPARTMENT
# Library                                1      LIBRARY ASSISTANT      26125.0
# Houston Police Department-HPD          2         POLICE OFFICER      45279.0
# Houston Fire Department (HFD)          3      ENGINEER/OPERATOR      63166.0
# General Services Department            4            ELECTRICIAN      56347.0
# Houston Police Department-HPD          5  SENIOR POLICE OFFICER      66614.0
#
#                                                     RACE EMPLOYMENT_TYPE  \
# DEPARTMENT
# Library                                  Hispanic/Latino       Full Time
# Houston Police Department-HPD                      White       Full Time
# Houston Fire Department (HFD)                      White       Full Time
# General Services Department                        White       Full Time
# Houston Police Department-HPD  Black or African American       Full Time
#
# ...

# %%
np.random.seed(1234)
random_salary = dept_sal.sample(n=10).set_index('DEPARTMENT')
random_salary
# Out:
#                                 BASE_SALARY
# DEPARTMENT
# Public Works & Engineering-PWE      50586.0
# Houston Police Department-HPD       66614.0
# Houston Police Department-HPD       66614.0
# Housing and Community Devp.         78853.0
# Houston Police Department-HPD       66614.0
# Parks & Recreation                      NaN
# Public Works & Engineering-PWE      37211.0
# Public Works & Engineering-PWE      54683.0
# Human Resources Dept.               58474.0
# Health & Human Services             47050.0

# %%
employee['RANDOM_SALARY']  = random_salary['BASE_SALARY']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-76e0397c41d3> in <module>()
# ----> 1 employee['RANDOM_SALARY']  = random_salary['BASE_SALARY']
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3361
#    3362         if isinstance(value, Series):
# ...

# %%
employee['MAX_SALARY2'] = max_dept_sal['BASE_SALARY'].head(3)
employee.MAX_SALARY2.value_counts()
# Out:
# 140416.0    29
# 100000.0    11
# 64251.0      5
# Name: MAX_SALARY2, dtype: int64

# %% [markdown]
# ### 각 열의 최댓값 부각하기

# %%
pwd = %pwd
college = pd.read_csv(pwd+'/college.csv', index_col= 'INSTNM')
college.dtypes
# Out:
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %%
college.MD_EARN_WNE_P10.iloc[0]
# Out:
# '30300'

# %%
college.GRAD_DEBT_MDN_SUPP.iloc[0]
# Out:
# '33888'

# %%
college.MD_EARN_WNE_P10.sort_values(ascending=False).head()
# Out:
# INSTNM
# Sharon Regional Health System School of Nursing    PrivacySuppressed
# Northcoast Medical Training Academy                PrivacySuppressed
# Success Schools                                    PrivacySuppressed
# Louisiana Culinary Institute                       PrivacySuppressed
# Bais Medrash Toras Chesed                          PrivacySuppressed
# Name: MD_EARN_WNE_P10, dtype: object

# %%
cols = ['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']
for col in cols :
    college[col] = pd.to_numeric(college[col], errors = 'coerce')
college.dtypes.loc[cols]
# Out:
# MD_EARN_WNE_P10       float64
# GRAD_DEBT_MDN_SUPP    float64
# dtype: object

# %%
college_n = college.select_dtypes(include=[np.number])
college_n.head()
# Out:
#                                      HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Alabama A & M University              1.0      0.0        0.0         0
# University of Alabama at Birmingham   0.0      0.0        0.0         0
# Amridge University                    0.0      0.0        0.0         1
# University of Alabama in Huntsville   0.0      0.0        0.0         0
# Alabama State University              1.0      0.0        0.0         0
#
#                                      SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                424.0     420.0           0.0
# University of Alabama at Birmingham     570.0     565.0           0.0
# Amridge University                        NaN       NaN           1.0
# University of Alabama in Huntsville     595.0     590.0           0.0
# Alabama State University                425.0     430.0           0.0
#
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# ...

# %%
criteria = college_n.nunique() == 2
criteria.head()
# Out:
# HBCU          True
# MENONLY       True
# WOMENONLY     True
# RELAFFIL      True
# SATVRMID     False
# dtype: bool

# %%
binary_cols = college_n.columns[criteria].tolist()
binary_cols
# Out:
# ['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER']

# %%
college_n2 = college_n.drop(labels=binary_cols, axis = 'columns')
college_n2.head()
# Out:
#                                      SATVRMID  SATMTMID     UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                424.0     420.0   4206.0      0.0333
# University of Alabama at Birmingham     570.0     565.0  11383.0      0.5922
# Amridge University                        NaN       NaN    291.0      0.2990
# University of Alabama in Huntsville     595.0     590.0   5451.0      0.6988
# Alabama State University                425.0     430.0   4811.0      0.0158
#
#                                      UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                 0.9353     0.0055      0.0019
# University of Alabama at Birmingham      0.2600     0.0283      0.0518
# Amridge University                       0.4192     0.0069      0.0034
# University of Alabama in Huntsville      0.1255     0.0382      0.0376
# Alabama State University                 0.9208     0.0121      0.0019
#
# ...

# %%
max_cols = college_n2.idxmax()
max_cols
# Out:
# SATVRMID                             California Institute of Technology
# SATMTMID                             California Institute of Technology
# UGDS                                      University of Phoenix-Arizona
# UGDS_WHITE                       Mr Leon's School of Hair Design-Moscow
# UGDS_BLACK                           Velvatex College of Beauty Culture
# UGDS_HISP                       Thunderbird School of Global Management
# UGDS_ASIAN                          Cosmopolitan Beauty and Tech School
# UGDS_AIAN                             Haskell Indian Nations University
# UGDS_NHPI                                       Palau Community College
# UGDS_2MOR                                                 LIU Brentwood
# UGDS_NRA               California University of Management and Sciences
# UGDS_UNKN             Le Cordon Bleu College of Culinary Arts-San Fr...
# PPTUG_EF                        Thunderbird School of Global Management
# ...

# %%
unique_max_cols = max_cols.unique()
unique_max_cols[:5]
# Out:
# array(['California Institute of Technology',
#        'University of Phoenix-Arizona',
#        "Mr Leon's School of Hair Design-Moscow",
#        'Velvatex College of Beauty Culture',
#        'Thunderbird School of Global Management'], dtype=object)

# %%
college_n2.loc[unique_max_cols].style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_a4cf3240_8379_11e8_9632_f45c898bd271row0_col0 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row0_col1 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row1_col2 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row2_col3 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row3_col4 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row4_col5 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row4_col12 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row5_col6 {
#             background-color:  yellow;
#         }    #T_a4cf3240_8379_11e8_9632_f45c898bd271row6_col7 {
#             background-color:  yellow;
# ...

# %%
pwd = %pwd
college = pd.read_csv(pwd+'/college.csv', index_col= 'INSTNM')
college_ugds = college.filter(like='UGDS_').head()
college_ugds.style.highlight_max(axis = 'columns')
# Out:
# <style  type="text/css" >
#     #T_e2da886e_8379_11e8_8056_f45c898bd271row0_col1 {
#             background-color:  yellow;
#         }    #T_e2da886e_8379_11e8_8056_f45c898bd271row1_col0 {
#             background-color:  yellow;
#         }    #T_e2da886e_8379_11e8_8056_f45c898bd271row2_col1 {
#             background-color:  yellow;
#         }    #T_e2da886e_8379_11e8_8056_f45c898bd271row3_col0 {
#             background-color:  yellow;
#         }    #T_e2da886e_8379_11e8_8056_f45c898bd271row4_col1 {
#             background-color:  yellow;
#         }</style>
# <table id="T_e2da886e_8379_11e8_8056_f45c898bd271" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >UGDS_WHITE</th>
#         <th class="col_heading level0 col1" >UGDS_BLACK</th>
#         <th class="col_heading level0 col2" >UGDS_HISP</th>
#         <th class="col_heading level0 col3" >UGDS_ASIAN</th>
# ...

# %% [markdown]
# - DataFrame Styling 에 관한 pandas 문서 : https://pandas.pydata.org/pandas-docs/stable/style.html

# %% [markdown]
# ### 메서드 체인을 사용한 idxmax 복제

# %%
pwd = %pwd
college = pd.read_csv(pwd+'/college.csv', index_col= 'INSTNM')
cols = ['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']

for col in cols:
    college[col] = pd.to_numeric(college[col], errors = 'coerce')
    
college_n = college.select_dtypes(include=[np.number])
criteria = college_n.nunique() == 2
binary_cols = college_n.columns[criteria].tolist()
college_n = college_n.drop(labels=binary_cols, axis = 'columns')

# %%
college_n.max().head()
# Out:
# SATVRMID         765.0
# SATMTMID         785.0
# UGDS          151558.0
# UGDS_WHITE         1.0
# UGDS_BLACK         1.0
# dtype: float64

# %%
college_n.eq(college_n.max()).head()
# Out:
#                                      SATVRMID  SATMTMID   UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                False     False  False       False
# University of Alabama at Birmingham     False     False  False       False
# Amridge University                      False     False  False       False
# University of Alabama in Huntsville     False     False  False       False
# Alabama State University                False     False  False       False
#
#                                      UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                  False      False       False
# University of Alabama at Birmingham       False      False       False
# Amridge University                        False      False       False
# University of Alabama in Huntsville       False      False       False
# Alabama State University                  False      False       False
#
# ...

# %%
has_row_max = college_n.eq(college_n.max()).any(axis = 'columns')
has_row_max.head()
# Out:
# INSTNM
# Alabama A & M University               False
# University of Alabama at Birmingham    False
# Amridge University                     False
# University of Alabama in Huntsville    False
# Alabama State University               False
# dtype: bool

# %%
college_n.shape
# Out:
# (7535, 18)

# %%
has_row_max.sum()
# Out:
# 401

# %%
college_n.eq(college_n.max()).cumsum()
# Out:
#                                                     SATVRMID  SATMTMID  UGDS  \
# INSTNM
# Alabama A & M University                                   0         0     0
# University of Alabama at Birmingham                        0         0     0
# Amridge University                                         0         0     0
# University of Alabama in Huntsville                        0         0     0
# Alabama State University                                   0         0     0
# The University of Alabama                                  0         0     0
# Central Alabama Community College                          0         0     0
# Athens State University                                    0         0     0
# Auburn University at Montgomery                            0         0     0
# Auburn University                                          0         0     0
# Birmingham Southern College                                0         0     0
# ...

# %%
college_n.eq(college_n.max()).cumsum().cumsum()
# Out:
#                                                     SATVRMID  SATMTMID  UGDS  \
# INSTNM
# Alabama A & M University                                   0         0     0
# University of Alabama at Birmingham                        0         0     0
# Amridge University                                         0         0     0
# University of Alabama in Huntsville                        0         0     0
# Alabama State University                                   0         0     0
# The University of Alabama                                  0         0     0
# Central Alabama Community College                          0         0     0
# Athens State University                                    0         0     0
# Auburn University at Montgomery                            0         0     0
# Auburn University                                          0         0     0
# Birmingham Southern College                                0         0     0
# ...

# %%
has_row_max2 = college_n.eq(college_n.max()).cumsum().cumsum().eq(1).any(axis = 'columns')
has_row_max2.head()
# Out:
# INSTNM
# Alabama A & M University               False
# University of Alabama at Birmingham    False
# Amridge University                     False
# University of Alabama in Huntsville    False
# Alabama State University               False
# dtype: bool

# %%
has_row_max2.sum()
# Out:
# 16

# %%
idxmax_cols = has_row_max2[has_row_max2].index
idxmax_cols
# Out:
# Index(['Thunderbird School of Global Management',
#        'Southwest University of Visual Arts-Tucson', 'ABC Beauty College Inc',
#        'Velvatex College of Beauty Culture',
#        'California Institute of Technology',
#        'Le Cordon Bleu College of Culinary Arts-San Francisco',
#        'MTI Business College Inc', 'Dongguk University-Los Angeles',
#        'Mr Leon's School of Hair Design-Moscow',
#        'Haskell Indian Nations University', 'LIU Brentwood',
#        'Medical College of Wisconsin', 'Palau Community College',
#        'California University of Management and Sciences',
#        'Cosmopolitan Beauty and Tech School', 'University of Phoenix-Arizona'],
#       dtype='object', name='INSTNM')

# %%
set(college_n.idxmax().unique()) == set(idxmax_cols)
# Out:
# True

# %%
# %timeit college_n.idxmax().values
# Out:
# 922 µs ± 10.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college_n.eq(college_n.max()).cumsum().cumsum().eq(1).any(axis = 'columns')[lambda x: x].index
# Out:
# 5.28 ms ± 203 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### 가장 흔한 최대값 찾기

# %%
pwd = %pwd
college = pd.read_csv(pwd+'/college.csv', index_col= 'INSTNM')
college_ugds = college.filter(like = 'UGDS_')
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
highest_percentage_race = college_ugds.idxmax(axis = 'columns')
highest_percentage_race.head()
# Out:
# INSTNM
# Alabama A & M University               UGDS_BLACK
# University of Alabama at Birmingham    UGDS_WHITE
# Amridge University                     UGDS_BLACK
# University of Alabama in Huntsville    UGDS_WHITE
# Alabama State University               UGDS_BLACK
# dtype: object

# %%
highest_percentage_race.value_counts(normalize=True)
# Out:
# UGDS_WHITE    0.670352
# UGDS_BLACK    0.151586
# UGDS_HISP     0.129473
# UGDS_UNKN     0.023422
# UGDS_ASIAN    0.012074
# UGDS_AIAN     0.006110
# UGDS_NRA      0.004073
# UGDS_NHPI     0.001746
# UGDS_2MOR     0.001164
# dtype: float64

# %%
college_black = college_ugds[highest_percentage_race == 'UGDS_BLACK']
college_black = college_black.drop('UGDS_BLACK', axis = 'columns')
college_black.idxmax(axis = 'columns').value_counts(normalize = True)
# Out:
# UGDS_WHITE    0.661228
# UGDS_HISP     0.230326
# UGDS_UNKN     0.071977
# UGDS_NRA      0.018234
# UGDS_ASIAN    0.009597
# UGDS_2MOR     0.006718
# UGDS_NHPI     0.000960
# UGDS_AIAN     0.000960
# dtype: float64
