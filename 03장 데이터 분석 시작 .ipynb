# %% [markdown]
# # Pandas Cookbook

# %% [markdown]
# https://github.com/PacktPublishing/Pandas-Cookbook/tree/master/data

# %% [markdown]
# ## 3장. 데이터 분석 시작

# %% [markdown]
# ### 소개

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 데이터 분석 루틴 개발

# %% [markdown]
# 탐색적 데이터 분석(Exploratory Data Analysis, EDA)

# %%
college = pd.read_csv('/Users/chosikc/Sites/PandasCookbook/college.csv')
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY         ...          \
# 0        0.0         0     424.0     420.0           0.0         ...
# 1        0.0         0     570.0     565.0           0.0         ...
# 2        0.0         1       NaN       NaN           1.0         ...
# 3        0.0         0     595.0     590.0           0.0         ...
# 4        0.0         0     425.0     430.0           0.0         ...
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# ...

# %%
college.shape
# Out:
# (7535, 27)

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 27 columns):
# INSTNM                7535 non-null object
# CITY                  7535 non-null object
# STABBR                7535 non-null object
# HBCU                  7164 non-null float64
# MENONLY               7164 non-null float64
# WOMENONLY             7164 non-null float64
# RELAFFIL              7535 non-null int64
# SATVRMID              1185 non-null float64
# SATMTMID              1196 non-null float64
# DISTANCEONLY          7164 non-null float64
# UGDS                  6874 non-null float64
# UGDS_WHITE            6874 non-null float64
# UGDS_BLACK            6874 non-null float64
# UGDS_HISP             6874 non-null float64
# UGDS_ASIAN            6874 non-null float64
# UGDS_AIAN             6874 non-null float64
# UGDS_NHPI             6874 non-null float64
# UGDS_2MOR             6874 non-null float64
# UGDS_NRA              6874 non-null float64
# ...

# %%
college.describe(include=[np.number]).head()
# 수치 열 요약 통계량을 구함
# Out:
#               HBCU      MENONLY    WOMENONLY     RELAFFIL     SATVRMID  \
# count  7164.000000  7164.000000  7164.000000  7535.000000  1185.000000
# mean      0.014238     0.009213     0.005304     0.190975   522.819409
# std       0.118478     0.095546     0.072642     0.393096    68.578862
# min       0.000000     0.000000     0.000000     0.000000   290.000000
# 25%       0.000000     0.000000     0.000000     0.000000   475.000000
#
#           SATMTMID  DISTANCEONLY         UGDS   UGDS_WHITE   UGDS_BLACK  \
# count  1196.000000   7164.000000  6874.000000  6874.000000  6874.000000
# mean    530.765050      0.005583  2356.837940     0.510207     0.189997
# std      73.469767      0.074519  5474.275871     0.286958     0.224587
# min     310.000000      0.000000     0.000000     0.000000     0.000000
# 25%     482.000000      0.000000   117.000000     0.267500     0.036125
#
#           ...         UGDS_AIAN    UGDS_NHPI    UGDS_2MOR     UGDS_NRA  \
# ...

# %%
college.describe(include=[np.number]).T
# T 전치(transpose)
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
college.describe(include=[np.object, pd.Categorical]).T
# 객체와 범주형 열에 대한 요약 통계량을 구함
# Out:
#                    count unique                         top  freq
# INSTNM              7535   7535  Westwood College-Annandale     1
# CITY                7535   2514                    New York    87
# STABBR              7535     59                          CA   773
# MD_EARN_WNE_P10     6413    598           PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038           PrivacySuppressed  1510

# %% [markdown]
# - 데이터는 연속형, 범주형으로 나눌 수 있음 <br>
# - 연속형 데이터 : 항상 수치, 가능한 값이 무한개 <br>
# - 범주형 데이터 : 가능한 값이 한정된 이산된 값 <br>

# %%
college.describe(include=[np.number], percentiles=[.01, .05, .10, .25, .5, .75, .9, .95, .99]).T
# Out:
#                count         mean          std    min          1%          5%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.000000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.000000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.000000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.000000
# SATVRMID      1185.0   522.819409    68.578862  290.0  390.000000  430.000000
# SATMTMID      1196.0   530.765050    73.469767  310.0  395.000000  430.000000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.000000
# UGDS          6874.0  2356.837940  5474.275871    0.0   14.000000   31.650000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.000000    0.013265
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.000000    0.000000
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.000000    0.000000
# ...

# %%
pd.read_csv('/Users/chosikc/Sites/PandasCookbook/college_data_dictionary.csv')
# Out:
#            column_name                                        description
# 0               INSTNM                                   Institution Name
# 1                 CITY                                      City Location
# 2               STABBR                                 State Abbreviation
# 3                 HBCU           Historically Black College or University
# 4              MENONLY                                       0/1 Men Only
# 5            WOMENONLY                                     0/1 Women only
# 6             RELAFFIL                          0/1 Religious Affiliation
# 7             SATVRMID                                  SAT Verbal Median
# 8             SATMTMID                                    SAT Math Median
# 9         DISTANCEONLY                            Distance Education Only
# 10                UGDS                           Undergraduate Enrollment
# 11          UGDS_WHITE                            Percent Undergrad White
# ...

# %% [markdown]
# - NumPy 데이터 계층 구조 : https://docs.scipy.org/doc/numpy-1.13.0/reference/arrays.scalars.html

# %% [markdown]
# ### 데이터 형식 변경을 통한 메모리 절약

# %%
college = pd.read_csv('/Users/chosikc/Sites/PandasCookbook/college.csv')
different_cols = ['RELAFFIL', 'SATMTMID', 'CURROPER', 'INSTNM', 'STABBR']

col2 = college.loc[:, different_cols]
col2.head()
# Out:
#    RELAFFIL  SATMTMID  CURROPER                               INSTNM STABBR
# 0         0     420.0         1             Alabama A & M University     AL
# 1         0     565.0         1  University of Alabama at Birmingham     AL
# 2         1       NaN         1                   Amridge University     AL
# 3         0     590.0         1  University of Alabama in Huntsville     AL
# 4         0     430.0         1             Alabama State University     AL

# %%
col2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
original_mem = col2.memory_usage(deep=True)
original_mem
# Out:
# Index           80
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660216
# STABBR      444565
# dtype: int64

# %%
col2['RELAFFIL'] = col2['RELAFFIL'].astype(np.int8)

# %%
col2.dtypes

# RELAFFIL  이  int64 에서 int8 으로 변경되었다.
# Out:
# RELAFFIL       int8
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
original_mem = col2.memory_usage(deep = True)
original_mem
# Out:
# Index           80
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660216
# STABBR      444565
# dtype: int64

# %%
college[different_cols].memory_usage(deep=True)
# Out:
# Index           80
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660216
# STABBR      444565
# dtype: int64

# %%
col2.select_dtypes(include=['object']).nunique()
# 중복이 심한 고유값이 적은 객체는 범주형으로 변경
# Out:
# INSTNM    7535
# STABBR      59
# dtype: int64

# %%
col2['STABBR'] = col2['STABBR'].astype('category')
col2.dtypes
# Out:
# RELAFFIL        int8
# SATMTMID     float64
# CURROPER       int64
# INSTNM        object
# STABBR      category
# dtype: object

# %%
new_mem = col2.memory_usage(deep=True)
new_mem
# Out:
# Index           80
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660641
# STABBR       13576
# dtype: int64

# %%
new_mem / original_mem
# Out:
# Index       1.000000
# RELAFFIL    1.000000
# SATMTMID    1.000000
# CURROPER    1.000000
# INSTNM      1.000644
# STABBR      0.030538
# dtype: float64

# %% [markdown]
# - 정확한 메모리 사용량을 확인하기 위해서는 memory_usage 메서드와 deep 매개변수를 True 로 사용해야 한다.

# %%
college.loc[0, 'CURROPER'] = 10000000
college.loc[0, 'INSTNM'] = college.loc[0, 'INSTNM'] + 'a'
college[['CURROPER', 'INSTNM']].memory_usage(deep= True)
# Out:
# Index           80
# CURROPER     60280
# INSTNM      660751
# dtype: int64

# %%
college['MENONLY'].dtype
# Out:
# dtype('float64')

# %%
college['MENONLY'].astype(np.int8)

#누락값이 포함되어 있어서 ValueError 가 발생한다.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-441c2371a12a> in <module>()
# ----> 1 college['MENONLY'].astype(np.int8)
#       2
#       3 #누락값이 포함되어 있어서 ValueError 가 발생한다.
#
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...

# %%
college.describe(include=['int64', 'float64']).T
college.describe(include=[np.int64, np.float64]).T
college.describe(include=['int', 'float']).T
college.describe(include=['number']).T
# Out:
#                count         mean            std    min         25%  \
# HBCU          7164.0     0.014238       0.118478    0.0    0.000000
# MENONLY       7164.0     0.009213       0.095546    0.0    0.000000
# WOMENONLY     7164.0     0.005304       0.072642    0.0    0.000000
# RELAFFIL      7535.0     0.190975       0.393096    0.0    0.000000
# SATVRMID      1185.0   522.819409      68.578862  290.0  475.000000
# SATMTMID      1196.0   530.765050      73.469767  310.0  482.000000
# DISTANCEONLY  7164.0     0.005583       0.074519    0.0    0.000000
# UGDS          6874.0  2356.837940    5474.275871    0.0  117.000000
# UGDS_WHITE    6874.0     0.510207       0.286958    0.0    0.267500
# UGDS_BLACK    6874.0     0.189997       0.224587    0.0    0.036125
# UGDS_HISP     6874.0     0.161635       0.221854    0.0    0.027600
# UGDS_ASIAN    6874.0     0.033544       0.073777    0.0    0.002500
# UGDS_AIAN     6874.0     0.013813       0.070196    0.0    0.000000
# ...

# %%
college['MENONLY'] = college['MENONLY'].astype('float16')
college['RELAFFIL'] = college['RELAFFIL'].astype('int8')

# %%
college.index = pd.Int64Index(college.index)
college.index.memory_usage()
# Out:
# 60280

# %% [markdown]
# - 데이터 형식에 대한 pandas 문서 : http://pandas.pydata.org/pandas-docs/stable/basics.html#dtypes

# %% [markdown]
# ### 최대에서 최소 선택

# %%
movie = pd.read_csv('/Users/chosikc/Sites/PandasCookbook/movie.csv')
movie2 = movie[['movie_title', 'imdb_score', 'budget']]
movie2.head()
# Out:
#                                   movie_title  imdb_score       budget
# 0                                      Avatar         7.9  237000000.0
# 1    Pirates of the Caribbean: At World's End         7.1  300000000.0
# 2                                     Spectre         6.8  245000000.0
# 3                       The Dark Knight Rises         8.5  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
movie2.nlargest(100, 'imdb_score').head()

# 상위 100위 작품을 선택하기 위해서 nlargest 메소드를 사용
# Out:
#                    movie_title  imdb_score      budget
# 2725          Towering Inferno         9.5         NaN
# 1920  The Shawshank Redemption         9.3  25000000.0
# 3402             The Godfather         9.2   6000000.0
# 2779                   Dekalog         9.1         NaN
# 4312      Kickboxer: Vengeance         9.1  17000000.0

# %%
movie2.nlargest(100, 'imdb_score').nsmallest(5, 'budget')

# 상위 100위 작품 중 최저 예산 영화 5개를 확인
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %% [markdown]
# ### 정렬에 의해 각 그룹의 최대 선택

# %%
movie = pd.read_csv('/Users/chosikc/Sites/PandasCookbook/movie.csv')
movie2 = movie[['movie_title', 'title_year', 'imdb_score']]

# %%
movie2.sort_values('title_year', ascending=False).head()

# sort_values 메소드를 사용해서 정렬한다.
# Out:
#                        movie_title  title_year  imdb_score
# 3884                      The Veil      2016.0         4.7
# 2375    My Big Fat Greek Wedding 2      2016.0         6.1
# 2794          Miracles from Heaven      2016.0         6.8
# 92    Independence Day: Resurgence      2016.0         5.5
# 153                Kung Fu Panda 3      2016.0         7.2

# %%
movie3 = movie2.sort_values(['title_year', 'imdb_score'],  ascending=False)
movie3.head()

# 연도와 점수를 동시에 정렬한다.
# Out:
#                       movie_title  title_year  imdb_score
# 4312         Kickboxer: Vengeance      2016.0         9.1
# 4277  A Beginner's Guide to Snuff      2016.0         8.7
# 3798                      Airlift      2016.0         8.5
# 27     Captain America: Civil War      2016.0         8.2
# 98            Godzilla Resurgence      2016.0         8.2

# %%
movie_top_year = movie3.drop_duplicates(subset='title_year')
movie_top_year.head()

# drop_duplicates 메소드를 사용해서 각 연도의 첫행만 남긴다. 즉, 각 연도별 가장 높은 점수의 영화리스트를 구했다.
# Out:
#                                   movie_title  title_year  imdb_score
# 4312                     Kickboxer: Vengeance      2016.0         9.1
# 3745                          Running Forever      2015.0         8.6
# 4369                   Queen of the Mountains      2014.0         8.7
# 3935  Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 3                       The Dark Knight Rises      2012.0         8.5

# %%
movie4 = movie[['movie_title', 'title_year', 'content_rating', 'budget']]
movie4_sorted = movie4.sort_values(['title_year', 'content_rating', 'budget'], ascending= [False, False, True])

#  title_year', 'content_rating' 는 내림차순으로, 'budget' 은 오른차순으로 정렬한다.

movie4_sorted.drop_duplicates(subset=['title_year', 'content_rating']).head(10)

# 상위 10개를 리스팅한다.
# Out:
#                                           movie_title  title_year  \
# 4026                                        Compadres      2016.0
# 4658                              Fight to the Finish      2016.0
# 4661                                       Rodeo Girl      2016.0
# 3252                                      The Wailing      2016.0
# 4659                   Alleluia! The Devil's Carnival      2016.0
# 4731                                          Bizarre      2015.0
# 812                                  The Ridiculous 6      2015.0
# 4831                                      The Gallows      2015.0
# 4825                                 Romantic Schemer      2015.0
# 3796  R.L. Stine's Monsterville: The Cabinet of Souls      2015.0
#
#      content_rating     budget
# 4026              R  3000000.0
# 4658          PG-13   150000.0
# 4661             PG   500000.0
# 3252      Not Rated        NaN
# 4659            NaN   500000.0
# 4731        Unrated   500000.0
# ...

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### sort_values를 사용해 nlargest를 복제

# %%
movie = pd.read_csv('/Users/chosikc/Sites/PandasCookbook/movie.csv')
movie2 = movie[['movie_title', 'imdb_score', 'budget']]

movie_smallest_largest = movie2.nlargest(100, 'imdb_score').nsmallest(5, 'budget')
movie_smallest_largest.head()
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %%
movie2.sort_values('imdb_score', ascending=False).head(100)

# imdb_score 상위 100개 리스트를 구한다.
# Out:
#                                             movie_title  imdb_score  \
# 2725                                   Towering Inferno         9.5
# 1920                           The Shawshank Redemption         9.3
# 3402                                      The Godfather         9.2
# 2779                                            Dekalog         9.1
# 4312                               Kickboxer: Vengeance         9.1
# 3415                                              Fargo         9.0
# 2791                             The Godfather: Part II         9.0
# 66                                      The Dark Knight         9.0
# 1857                                   Schindler's List         8.9
# 335       The Lord of the Rings: The Return of the King         8.9
# 3295                                       Pulp Fiction         8.9
# 4706                                       12 Angry Men         8.9
# 4397                     The Good, the Bad and the Ugly         8.9
# ...

# %%
movie2.sort_values('imdb_score', ascending=False).head(100).sort_values('budget').head()

# 상위 100개 점수의 영화에서 budget이 낮은 5개를 구한다.
# Out:
#                     movie_title  imdb_score    budget
# 4815  A Charlie Brown Christmas         8.4  150000.0
# 4801         Children of Heaven         8.5  180000.0
# 4804             Butterfly Girl         8.7  180000.0
# 4706               12 Angry Men         8.9  350000.0
# 4636       The Other Dream Team         8.4  500000.0

# %%
movie2.nlargest(100, 'imdb_score').tail()
# Out:
#                 movie_title  imdb_score     budget
# 4023                 Oldboy         8.4  3000000.0
# 4163  To Kill a Mockingbird         8.4  2000000.0
# 4395         Reservoir Dogs         8.4  1200000.0
# 4550           A Separation         8.4   500000.0
# 4636   The Other Dream Team         8.4   500000.0

# %%
movie2.sort_values('imdb_score', ascending=False).head(100).tail()

# nlargest 와 sort_values 의 메서드는 동률이 발생할 경우, 처리 방법이 달라서 DataFrame의 값이 다르다.
# Out:
#                                   movie_title  imdb_score      budget
# 3799                     Anne of Green Gables         8.4         NaN
# 3777                      Requiem for a Dream         8.4   4500000.0
# 3935  Batman: The Dark Knight Returns, Part 2         8.4   3500000.0
# 4636                     The Other Dream Team         8.4    500000.0
# 2455                                   Aliens         8.4  18500000.0

# %% [markdown]
# ### 추적 지정 주문가 계산

# %% [markdown]
# * stop order 관련 코드는 pandas_datareader 이슈로 추후 학습한다.
